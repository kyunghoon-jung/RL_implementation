# %% [markdown]
# #### 분산 강화학습으로 CartPole을 DQN을 이용하여 구현해보겠습니다. <br>앞선 ReplayBuffer의 경우에 추가적으로 다음을 고려해야합니다. ReplayBuffer에서 설명했던 변수들은 설명을 생략하였습니다. <br>
#     1. ReplayBuffer에서 Learner가 어떤 주기로 weight update를 할지
#     2. 각 Actor의 network parameter를 어떤 식으로 Learner로 부터 copy해 올지 --> 비동기? vs 동기?

# %%
import ray 
import gym
import time 
import numpy as np 
import matplotlib.pyplot as plt
from IPython.display import clear_output

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
ray.init()
# Out:
# 2021-01-23 08:13:42,097	INFO services.py:1173 -- View the Ray dashboard at http://127.0.0.1:8265
# {'node_ip_address': '192.168.0.61',
#  'raylet_ip_address': '192.168.0.61',
#  'redis_address': '192.168.0.61:6379',
#  'object_store_address': '/tmp/ray/session_2021-01-23_08-13-41_603694_109332/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2021-01-23_08-13-41_603694_109332/sockets/raylet',
#  'webui_url': '127.0.0.1:8265',
#  'session_dir': '/tmp/ray/session_2021-01-23_08-13-41_603694_109332',
#  'metrics_export_port': 57577,
#  'node_id': 'b573591ed7e6015cb640574f8896baacbafba292'}

# %%
# Buffer를 정의합니다.
@ray.remote
class ReplayBuffer:
    def __init__(self, 
                 buffer_size: ('int: Buffer_size'), 
                 state_dim: ('tuple: State dim')):
        
        # 1차원 state라할지라도 tuple로 입력받도록 tuple 타입을 강제하였습니다. 밑에 줄의 self.buffer_dim을 구하기 위해서 이렇게 한 것인데요, 사실 빼도 상관없고 얼마든지 다르게 구현해도 무방합니다.
        assert type(state_dim) == tuple 
        
        self.buffer_dim = (buffer_size, ) + state_dim
        self.buffer_size = buffer_size
        self.state_buffer = np.zeros(self.buffer_dim)
        self.action_buffer = np.zeros(buffer_size)
        self.reward_buffer = np.zeros(buffer_size)
        self.next_state_buffer = np.zeros(self.buffer_dim)
        self.done_buffer = np.zeros(buffer_size)
        self.act_idx_buffer = np.zeros(buffer_size)
        
        self.store_idx = 0
        self.current_size = 0

    def store(self, state, action, next_state, reward, done, actor_idx):
        self.state_buffer[self.store_idx] = state
        self.action_buffer[self.store_idx] = action
        self.reward_buffer[self.store_idx] = reward
        self.next_state_buffer[self.store_idx] = next_state
        self.done_buffer[self.store_idx] = done
        self.act_idx_buffer[self.store_idx] = actor_idx
        
        self.store_idx = (self.store_idx + 1) % self.buffer_size
        self.current_size = min(self.current_size+1, self.buffer_size)
    
    def batch_load(self, batch_size): 
        indices = np.random.randint(self.store_idx, size=batch_size)  
        return dict( 
                states=self.state_buffer[indices], 
                actions=self.action_buffer[indices], 
                rewards=self.reward_buffer[indices], 
                next_states=self.next_state_buffer[indices], 
                dones=self.done_buffer[indices],
                actindices=self.act_idx_buffer[indices])  

# buffer_size = 1000
# batch_size = 16
# state_dim = (4, )
# temp_buffer = ReplayBuffer.remote(buffer_size, state_dim)
# for i in range(50):
#     temp_buffer.store.remote(np.array(state_dim), 1, np.array(state_dim), 1, 1, 1)
# batch = temp_buffer.batch_load.remote(batch_size)
# ray.get(batch)['actindices'].shape

# %%
class QNetwork(nn.Module):
    def __init__(self, state_size, action_size, hidden=32):
        super(QNetwork, self).__init__()

        state_size = state_size[0]
        self.fc1 = nn.Linear(state_size, hidden)
        self.fc2 = nn.Linear(hidden, action_size)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# state_size = (4, ) 
# action_size = 2 
# temp_net = QNetwork(state_size, action_size, 32) 
# test = torch.randn(size=(4,)) 
# temp_net(test), temp_net(test).shape

# %%
# actor의 역할은 각각 env에서 경험한 것을 buffer에 넘겨주는 역할을 합니다.
@ray.remote
class Actor:
    def __init__(self, 
                 learner: ("class: Learner class"),
                 env_name: ("str: Environment name"), 
                 actor_idx: ("int: The index of an actor"), 
                 actor_update_freq: ("int: Update frequency of an actor"), 
                 epsilon: ("int: starting epsilon value for e-greedy update"), 
                 eps_decay: ("int: epsilon decay rate"), 
                 eps_min: ("int: minimum epsilon value"), 
                 hidden: ("int: Update frequency of learner's q_behave network"), 
                 device: ("int: Cuda device number")):
        
        self.env = gym.make(env_name)
        self.learner = learner # ray를 통해 공유하는 learner class입니다.
        self.actor_idx = actor_idx # 어떤 actor에서 온 데이터인지 보기 위한 변수입니다.
        self.actor_update_freq = actor_update_freq # actor의 network weight를 얼마나 자주 업데이트 할 것인지 
        self.device = device
        
        # DQN hyperparameters
        self.epsilon = epsilon
        self.eps_decay = eps_decay
        self.eps_min = eps_min

        # Network parameters
        self.state_dim = (self.env.observation_space.shape[0], )
        self.action_dim = self.env.action_space.n
        self.q_behave = QNetwork(self.state_dim, self.action_dim, hidden).to(self.device)

    def select_action(self, state): 
        # e-greedy로 action을 선택 
        if np.random.random() < self.epsilon: 
            return np.zeros(self.action_dim), self.env.action_space.sample() 
        else: 
            state = torch.FloatTensor(state).to(self.device).unsqueeze(0) 
            Qs = self.q_behave(state) 
            action = Qs.argmax() 
            return Qs.detach().cpu().numpy(), action.detach().item() 
        
    def explore(self):
        score = 0
        episodes_cnt = 0
        # actor는 멈추지 않고 무한 loop로 exploration하도록 설정
        state = self.env.reset()
        while 1:
            Qs, action = self.select_action(state)
            next_state, reward, done, _ = self.env.step(action) 
            self.learner.store.remote(state, action, next_state, reward, done, self.actor_idx) 
            print("store executed in actor idx", self.actor_idx)

            state = next_state
            score += reward
            self.epsilon = max(self.epsilon-self.eps_decay, self.eps_min)
            if done:
                print(f"Done in actor index: {self.actor_idx}")
                state = self.env.reset() 
                score = 0
                episodes_cnt = (episodes_cnt+1) % self.actor_update_freq
                if episodes_cnt==0: 
                    print("GET_WEIGHT")
                    self.get_weights()
                    print("GET_WEIGHT")

    def get_weights(self):
        weight_copy = self.learner.return_weights.remote()
        weight_copy = ray.get(weight_copy)
        print(type(weight_copy), self.actor_idx)
        self.q_behave.load_state_dict(weight_copy)

# %%
# 공유 Buffer를 통해 학습을 진행하는 Learner를 정의합니다. 
# Learner는 buffer에 있는 샘플을 이용하여 network parameter를 업데이트를 하며, agent에게 network weight을 전달합니다.

@ray.remote
class Learner:
    def __init__(self, 
                 env_name: ("str: Environment name"),
                 gamma: ("float: Discount rate"),
                 buffer_size: ("int: Buffer size"), 
                 batch_size: ("int: Batch size"), 
                 update_buf_start: ("int: Update starting buffer size"), 
                 update_freq: ("int: Update frequency of learner's q_behave network"), 
                 update_target_freq: ("int: Update frequency of learner's q_target network"), 
                 hidden: ("int: Update frequency of learner's q_behave network"), 
                 learning_rate: ("float: Learning rate for updating the q_behave network"),
                 device: ("int: Cuda device number")):
        
        self.env = gym.make(env_name)
        self.gamma = gamma
        # Discrete action과 Box state인 경우
        self.state_dim = (self.env.observation_space.shape[0], )
        self.action_dim = self.env.action_space.n
        
        self.memory = ReplayBuffer.remote(buffer_size, state_dim)
        
        self.batch_size = batch_size
        self.update_cnt = 0 # q_behave 업데이트 횟수
        self.update_freq = update_freq # q_behave 업데이트 주기
        self.update_buf_start = update_buf_start # 업데이트 시작 buffer size
        self.update_target_freq = update_target_freq # q_target 업데이트 주기
        self.device = device
        self.total_steps = 0
        self.scores = []
        self.losses = []

        self.q_behave = QNetwork(self.state_dim, self.action_dim, hidden).to(self.device)
        self.q_target = QNetwork(self.state_dim, self.action_dim, hidden).to(self.device)
        self.q_target.load_state_dict(self.q_behave.state_dict())
        self.q_target.eval()

        self.optimizer = optim.Adam(self.q_behave.parameters(), lr=learning_rate) 

    # __init__에서 정의된 replay buffer에 저장합니다. 이 메소드는 각 actor마다 실행됩니다. 
    def store(self, state, action, next_state, reward, done, actor_idx):
        print("self.total_steps_1", self.total_steps)
        self.total_steps += 1
        self.memory.store.remote(state, action, next_state, reward, done, actor_idx)

    # 저장된 buffer에서 데이터를 로딩한 후 q_network을 업데이트합니다.
    def update_q_network(self):
        # update_cnt를 q_behave를 업데이트 할 때마다 1씩 상승 (self.update_target_freq 만큼 q_behave를 업데이트를 할 때마다 q_target을 업데이트 하기 위함)
        self.update_cnt = (self.update_cnt+1) % self.target_update_freq

        batch = self.memory.batch_load.remote(self.batch_size)
        batch = ray.get(batch)
        loss = self._compute_loss(batch)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.losses.append(loss.item()) 

    def target_hard_update(self):  
        # Hard update 방식
        self.q_target.load_state_dict(self.q_behave.state_dict()) 

    def return_weights(self):
        return self.q_behave.state_dict() # target network을 return할지 or behave network을 할지는 선택사항인 것 같습니다.

    def select_action(self, state): 
        # e-greedy로 action을 선택 
        test_epsilon = 0.05
        if np.random.random() < test_epsilon: 
            return np.zeros(self.action_dim), self.env.action_space.sample() 
        else: 
            state = torch.FloatTensor(state).to(self.device).unsqueeze(0) 
            Qs = self.q_behave(state) 
            action = Qs.argmax() 
            return Qs.detach().cpu().numpy(), action.detach().item() 

    def train(self):
        # 여기서는 training의 종료시점을 정하지 않았습니다.
        print("training start..")
        loop_cnt = 0
        while 1:
            loop_cnt += 1
            score = 0
            state = self.env.reset()
            # buffer에 어느 정도 sample이 쌓인 후에, 그리고 update_freq 마다 learner의 q_behave를 업데이트 합니다.
            time.sleep(1)
            print("SELF.MEMORY.store_idx", self.memory.store_idx)
            if (self.memory.store_idx > self.update_buf_start) and ((self.memory.store_idx%self.update_freq) == 0):
                self.update_q_network()
                Qs, action = select_action(state)
                next_state, reward, done = self.env.step(action) 
                state = next_state
                score += reward
                
                if done:
                    self.scores.append(score)
                    self._plot_status()
                    score=0
                # 만일 target_update_freq의 횟수 만큼 q_behave를 업데이트 했다면, target_network을 복사해옵니다.
                if self.update_cnt==0: self.target_hard_update()

    def _compute_loss(self, batch: "Dictionary (S, A, R', S', Dones)"):
        states = torch.FloatTensor(batch['states']).to(self.device)
        next_states = torch.FloatTensor(batch['next_states']).to(self.device)
        actions = torch.LongTensor(batch['actions'].reshape(-1, 1)).to(self.device)
        rewards = torch.FloatTensor(batch['rewards'].reshape(-1, 1)).to(self.device)
        dones = torch.FloatTensor(batch['dones'].reshape(-1, 1)).to(self.device)

        current_q = self.q_behave(states).gather(1, actions)
        next_q = self.q_target(next_states).max(dim=1, keepdim=True)[0].detach()
        mask = 1 - dones
        target = (rewards + (mask * self.gamma * next_q)).to(self.device)

        loss = F.smooth_l1_loss(current_q, target)
        return loss

    def _plot_status(self):
        clear_output(True) 
        plt.figure(figsize=(20, 5), facecolor='w') 
        plt.subplot(121)  
        plt.title(f'Score w.r.t. Total number of steps {self.total_steps}.')
        plt.plot(self.scores) 
        plt.subplot(122) 
        plt.title('loss') 
        plt.plot(self.losses)

# %%
env_lists = ['CartPole-v0']
env_name = env_lists[0]
gamma = 0.99

buffer_size = 5000 # Replay Buffer 사이즈
batch_size = 16    # Replay Buffer에서 가지고 올 샘플 개수
update_buf_start = 100
update_freq = 25
update_target_freq = 100

hidden = 32
learning_rate = 0.001
# device = "cuda:1" if torch.cuda.is_available() else "cpu"
device = "cpu"

learner = Learner.remote(env_name, gamma, buffer_size, batch_size, update_buf_start, update_freq, update_target_freq, hidden, learning_rate, device)
# Out:
# 2021-01-23 08:13:58,194	ERROR worker.py:980 -- Possible unhandled error from worker: ray::Learner.__init__() (pid=109483, ip=192.168.0.61)
#   File "python/ray/_raylet.pyx", line 463, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 415, in ray._raylet.execute_task.function_executor
#   File "<ipython-input-6-8f267e0cb323>", line 18, in __init__
# NameError: name 'state_dim' is not defined

# %%
# num_actors 개수만큼 선언하고, explore 실행. actor라는 변수가 계속 중복이 되지만 실행은 잘 된다.
num_actors = 3 # actor의 개수
actor_update_freq = 5 # 몇 episode 만에 actor의 weight를 업데이트하는가
epsilon = 1.0
eps_decay = 0.0005
eps_min = 0.1

for actor_idx in range(num_actors):
    actor = Actor.remote(learner, env_name, actor_idx, actor_update_freq, epsilon, eps_decay, eps_min, hidden, device)
    actor.explore.remote()
    
learner.train.remote()
# Out:
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) GET_WEIGHT
# (pid=107496) self.total_steps_1 18704
# (pid=107496) self.total_steps_1 18705
# (pid=107496) self.total_steps_1 18706
# (pid=107496) self.total_steps_1 18707
# (pid=107496) self.total_steps_1 18708
# (pid=107496) self.total_steps_1 18709
# (pid=107496) self.total_steps_1 18710
# (pid=107493) <class 'collections.OrderedDict'> 2
# (pid=107493) GET_WEIGHT
# (pid=107496) self.total_steps_1 18711
# (pid=107496) self.total_steps_1 18712
# (pid=107496) self.total_steps_1 18713
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18714
# (pid=107496) self.total_steps_1 18715
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18716
# (pid=107496) self.total_steps_1 18717
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18718
# (pid=107496) self.total_steps_1 18719
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107496) self.total_steps_1 18720
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18721
# (pid=107496) self.total_steps_1 18722
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18723
# (pid=107496) self.total_steps_1 18724
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107496) self.total_steps_1 18725
# (pid=107496) self.total_steps_1 18726
# (pid=107496) self.total_steps_1 18727
# (pid=107496) self.total_steps_1 18728
# (pid=107496) self.total_steps_1 18729
# (pid=107496) self.total_steps_1 18730
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18731
# (pid=107496) self.total_steps_1 18732
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18733
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18734
# (pid=107493) store executed in actor idx 2
# (pid=107521) <class 'collections.OrderedDict'> 0
# (pid=107521) GET_WEIGHT
# (pid=107496) self.total_steps_1 18735
# (pid=107496) self.total_steps_1 18736
# (pid=107496) self.total_steps_1 18737
# (pid=107496) self.total_steps_1 18738
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18739
# (pid=107496) self.total_steps_1 18740
# (pid=107496) self.total_steps_1 18741
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18742
# (pid=107496) self.total_steps_1 18743
# (pid=107496) self.total_steps_1 18744
# (pid=107496) self.total_steps_1 18745
# (pid=107496) self.total_steps_1 18746
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18747
# (pid=107496) self.total_steps_1 18748
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18749
# (pid=107496) self.total_steps_1 18750
# (pid=107496) self.total_steps_1 18751
# (pid=107496) self.total_steps_1 18752
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107496) self.total_steps_1 18753
# (pid=107496) self.total_steps_1 18754
# (pid=107496) self.total_steps_1 18755
# (pid=107496) self.total_steps_1 18756
# (pid=107496) self.total_steps_1 18757
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18758
# (pid=107496) self.total_steps_1 18759
# (pid=107496) self.total_steps_1 18760
# (pid=107496) self.total_steps_1 18761
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18762
# (pid=107496) self.total_steps_1 18763
# (pid=107496) self.total_steps_1 18764
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107496) self.total_steps_1 18765
# (pid=107496) self.total_steps_1 18766
# (pid=107496) self.total_steps_1 18767
# (pid=107493)
# (pid=107493) Done in actor index: 2
# (pid=107493) GET_WEIGHT
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18768
# (pid=107496) self.total_steps_1 18769
# (pid=107496) self.total_steps_1 18770
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18771
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18772
# (pid=107496) self.total_steps_1 18773
# (pid=107496) self.total_steps_1 18774
# (pid=107496) self.total_steps_1 18775
# (pid=107496) self.total_steps_1 18776
# (pid=107496) self.total_steps_1 18777
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18778
# (pid=107496) self.total_steps_1 18779
# (pid=107496) self.total_steps_1 18780
# (pid=107496) self.total_steps_1 18781
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18782
# (pid=107496) self.total_steps_1 18783
# (pid=107496) self.total_steps_1 18784
# (pid=107496) self.total_steps_1 18785
# (pid=107496) self.total_steps_1 18786
# (pid=107496) self.total_steps_1 18787
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18788
# (pid=107496) self.total_steps_1 18789
# (pid=107496) self.total_steps_1 18790
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18791
# (pid=107521) store executed in actor idx 0
# (pid=107485) <class 'collections.OrderedDict'> 1
# (pid=107485) GET_WEIGHT
# (pid=107496) self.total_steps_1 18792
# (pid=107496) self.total_steps_1 18793
# (pid=107496) self.total_steps_1 18794
# (pid=107496) self.total_steps_1 18795
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) store executed in actor idx 0
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18796
# (pid=107496) self.total_steps_1 18797
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18798
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) GET_WEIGHT
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107496) self.total_steps_1 18799
# (pid=107496) self.total_steps_1 18800
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18801
# (pid=107485)
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18802
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107496) self.total_steps_1 18803
# (pid=107496) self.total_steps_1 18804
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18805
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18806
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18807
# (pid=107496) self.total_steps_1 18808
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# 2021-01-23 08:09:00,051	WARNING worker.py:907 -- The driver may not be able to keep up with the stdout/stderr of the workers. To avoid forwarding logs to the driver, use 'ray.init(log_to_driver=False)'.
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18809
# (pid=107496) self.total_steps_1 18810
# (pid=107496) self.total_steps_1 18811
# (pid=107496) self.total_steps_1 18812
# (pid=107496) self.total_steps_1 18813
# (pid=107496) self.total_steps_1 18814
# (pid=107496) self.total_steps_1 18815
# (pid=107496) self.total_steps_1 18816
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18817
# (pid=107496) self.total_steps_1 18818
# (pid=107496) self.total_steps_1 18819
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18820
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18821
# (pid=107496) self.total_steps_1 18822
# (pid=107496) self.total_steps_1 18823
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18824
# (pid=107496) self.total_steps_1 18825
# (pid=107496) self.total_steps_1 18826
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18827
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) GET_WEIGHT
# (pid=107496) self.total_steps_1 18828
# (pid=107496) self.total_steps_1 18829
# (pid=107496) self.total_steps_1 18830
# (pid=107496) self.total_steps_1 18831
# (pid=107496) self.total_steps_1 18832
# (pid=107496) self.total_steps_1 18833
# (pid=107496) self.total_steps_1 18834
# (pid=107496) self.total_steps_1 18835
# (pid=107496) self.total_steps_1 18836
# (pid=107496) self.total_steps_1 18837
# (pid=107496) self.total_steps_1 18838
# (pid=107496) self.total_steps_1 18839
# (pid=107496) self.total_steps_1 18840
# (pid=107496) self.total_steps_1 18841
# (pid=107496) self.total_steps_1 18842
# (pid=107496) self.total_steps_1 18843
# (pid=107496) self.total_steps_1 18844
# (pid=107496) self.total_steps_1 18845
# (pid=107496) self.total_steps_1 18846
# (pid=107496) self.total_steps_1 18847
# (pid=107496) self.total_steps_1 18848
# (pid=107496) self.total_steps_1 18849
# (pid=107496) self.total_steps_1 18850
# (pid=107496) self.total_steps_1 18851
# (pid=107496) self.total_steps_1 18852
# (pid=107496) self.total_steps_1 18853
# (pid=107496) self.total_steps_1 18854
# (pid=107496) self.total_steps_1 18855
# (pid=107496) self.total_steps_1 18856
# (pid=107496) self.total_steps_1 18857
# (pid=107496) self.total_steps_1 18858
# (pid=107496) self.total_steps_1 18859
# (pid=107496) self.total_steps_1 18860
# (pid=107496) self.total_steps_1 18861
# (pid=107496) self.total_steps_1 18862
# (pid=107496) self.total_steps_1 18863
# (pid=107496) self.total_steps_1 18864
# (pid=107496) self.total_steps_1 18865
# (pid=107496) self.total_steps_1 18866
# (pid=107496) self.total_steps_1 18867
# (pid=107496) self.total_steps_1 18868
# (pid=107496) self.total_steps_1 18869
# (pid=107496) self.total_steps_1 18870
# (pid=107496) self.total_steps_1 18871
# (pid=107496) self.total_steps_1 18872
# (pid=107496) self.total_steps_1 18873
# (pid=107496) self.total_steps_1 18874
# (pid=107496) self.total_steps_1 18875
# (pid=107493) <class 'collections.OrderedDict'> 2
# (pid=107493) GET_WEIGHT
# (pid=107496) self.total_steps_1 18876
# (pid=107496) self.total_steps_1 18877
# (pid=107496) self.total_steps_1 18878
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18879
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18880
# (pid=107496) self.total_steps_1 18881
# (pid=107496) self.total_steps_1 18882
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18883
# (pid=107496) self.total_steps_1 18884
# (pid=107496) self.total_steps_1 18885
# (pid=107496) self.total_steps_1 18886
# (pid=107496) self.total_steps_1 18887
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107496) self.total_steps_1 18888
# (pid=107496) self.total_steps_1 18889
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18890
# (pid=107496) self.total_steps_1 18891
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18892
# (pid=107496) self.total_steps_1 18893
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18894
# (pid=107496) self.total_steps_1 18895
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18896
# (pid=107496) self.total_steps_1 18897
# (pid=107496) self.total_steps_1 18898
# (pid=107496) self.total_steps_1 18899
# (pid=107496) self.total_steps_1 18900
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18901
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 18902
# (pid=107493) store executed in actor idx 2
# (pid=107521) <class 'collections.OrderedDict'> 0
# (pid=107521) GET_WEIGHT
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18903
# (pid=107496) self.total_steps_1 18904
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18905
# (pid=107496) self.total_steps_1 18906
# (pid=107496) self.total_steps_1 18907
# (pid=107496) self.total_steps_1 18908
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18909
# (pid=107496) self.total_steps_1 18910
# (pid=107496) self.total_steps_1 18911
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18912
# (pid=107496) self.total_steps_1 18913
# (pid=107496) self.total_steps_1 18914
# (pid=107496) self.total_steps_1 18915
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18916
# (pid=107496) self.total_steps_1 18917
# (pid=107496) self.total_steps_1 18918
# (pid=107496) self.total_steps_1 18919
# (pid=107496) self.total_steps_1 18920
# (pid=107496) self.total_steps_1 18921
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18922
# (pid=107496) self.total_steps_1 18923
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18924
# (pid=107496) self.total_steps_1 18925
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18926
# (pid=107496) self.total_steps_1 18927
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18928
# (pid=107496) self.total_steps_1 18929
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18930
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) GET_WEIGHT
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx
# (pid=107521) 0
# (pid=107496) self.total_steps_1 18931
# (pid=107496) self.total_steps_1 18932
# (pid=107496) self.total_steps_1 18933
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107496) self.total_steps_1 18934
# (pid=107496) self.total_steps_1 18935
# (pid=107496)
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18936
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18937
# (pid=107496) self.total_steps_1 18938
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18939
# (pid=107496) self.total_steps_1 18940
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18941
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18942
# (pid=107496) self.total_steps_1 18943
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18944
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18945
# (pid=107496) self.total_steps_1
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) 18946
# (pid=107496) self.total_steps_1 18947
# (pid=107496) self.total_steps_1
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) 18948
# (pid=107496) self.total_steps_1 18949
# (pid=107521)
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18950
# (pid=107496) self.total_steps_1 18951
# (pid=107496) self.total_steps_1
# (pid=107496)  18952
# (pid=107496)
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 18953
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) GET_WEIGHT
# (pid=107496) self.total_steps_1 18954
# (pid=107496) self.total_steps_1 18955
# (pid=107496) self.total_steps_1 18956
# (pid=107485) <class 'collections.OrderedDict'> 1
# (pid=107485) GET_WEIGHT
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18957
# (pid=107496) self.total_steps_1 18958
# (pid=107496) self.total_steps_1 18959
# (pid=107496) self.total_steps_1 18960
# (pid=107496) self.total_steps_1 18961
# (pid=107496) self.total_steps_1 18962
# (pid=107496) self.total_steps_1 18963
# (pid=107496) self.total_steps_1 18964
# (pid=107496) self.total_steps_1 18965
# (pid=107496) self.total_steps_1 18966
# (pid=107496) self.total_steps_1 18967
# (pid=107496) self.total_steps_1 18968
# (pid=107496) self.total_steps_1 18969
# (pid=107496) self.total_steps_1 18970
# (pid=107496) self.total_steps_1 18971
# (pid=107496) self.total_steps_1 18972
# (pid=107496) self.total_steps_1 18973
# (pid=107496) self.total_steps_1 18974
# (pid=107496) self.total_steps_1 18975
# (pid=107496) self.total_steps_1 18976
# (pid=107496) self.total_steps_1 18977
# (pid=107496) self.total_steps_1 18978
# (pid=107496) self.total_steps_1 18979
# (pid=107496) self.total_steps_1 18980
# (pid=107496) self.total_steps_1 18981
# (pid=107496) self.total_steps_1 18982
# (pid=107496) self.total_steps_1 18983
# (pid=107496) self.total_steps_1 18984
# (pid=107496) self.total_steps_1 18985
# (pid=107496) self.total_steps_1 18986
# (pid=107496) self.total_steps_1 18987
# (pid=107496) self.total_steps_1 18988
# (pid=107496) self.total_steps_1 18989
# (pid=107496) self.total_steps_1 18990
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18991
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107496) self.total_steps_1 18992
# (pid=107496) self.total_steps_1 18993
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18994
# (pid=107496) self.total_steps_1 18995
# (pid=107496) self.total_steps_1 18996
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18997
# (pid=107496) self.total_steps_1 18998
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 18999
# (pid=107496) self.total_steps_1 19000
# (pid=107496) self.total_steps_1 19001
# (pid=107496) self.total_steps_1 19002
# (pid=107496) self.total_steps_1 19003
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107496) self.total_steps_1 19004
# (pid=107496) self.total_steps_1 19005
# (pid=107496) self.total_steps_1 19006
# (pid=107496) self.total_steps_1 19007
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 19008
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) GET_WEIGHT
# (pid=107496) self.total_steps_1 19009
# (pid=107496) self.total_steps_1 19010
# (pid=107496) self.total_steps_1 19011
# (pid=107496) self.total_steps_1 19012
# (pid=107496) self.total_steps_1 19013
# (pid=107496) self.total_steps_1 19014
# (pid=107496) self.total_steps_1 19015
# (pid=107496) self.total_steps_1 19016
# (pid=107496) self.total_steps_1 19017
# (pid=107496) self.total_steps_1 19018
# (pid=107496) self.total_steps_1 19019
# (pid=107496) self.total_steps_1 19020
# (pid=107496) self.total_steps_1 19021
# (pid=107496) self.total_steps_1 19022
# (pid=107496) self.total_steps_1 19023
# (pid=107496) self.total_steps_1 19024
# (pid=107496) self.total_steps_1 19025
# (pid=107496) self.total_steps_1 19026
# (pid=107496) self.total_steps_1 19027
# (pid=107496) self.total_steps_1 19028
# (pid=107496) self.total_steps_1 19029
# (pid=107496) self.total_steps_1 19030
# (pid=107496) self.total_steps_1 19031
# (pid=107496) self.total_steps_1 19032
# (pid=107496) self.total_steps_1 19033
# (pid=107496) self.total_steps_1 19034
# (pid=107496) self.total_steps_1 19035
# (pid=107496) self.total_steps_1 19036
# (pid=107496) self.total_steps_1 19037
# (pid=107496) self.total_steps_1 19038
# (pid=107496) self.total_steps_1 19039
# (pid=107496) self.total_steps_1 19040
# (pid=107496) self.total_steps_1 19041
# (pid=107496) self.total_steps_1 19042
# (pid=107493) <class 'collections.OrderedDict'> 2
# (pid=107493) GET_WEIGHT
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19043
# (pid=107496) self.total_steps_1 19044
# (pid=107496) self.total_steps_1 19045
# (pid=107496) self.total_steps_1 19046
# (pid=107496) self.total_steps_1 19047
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19048
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19049
# (pid=107496) self.total_steps_1 19050
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107496) self.total_steps_1 19051
# (pid=107496) self.total_steps_1 19052
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19053
# (pid=107496) self.total_steps_1 19054
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19055
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19056
# (pid=107496) self.total_steps_1 19057
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19058
# (pid=107496) self.total_steps_1 19059
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19060
# (pid=107496) self.total_steps_1 19061
# (pid=107496) self.total_steps_1 19062
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19063
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19064
# (pid=107496) self.total_steps_1 19065
# (pid=107496) self.total_steps_1 19066
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19067
# (pid=107496) self.total_steps_1 19068
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107496) self.total_steps_1 19069
# (pid=107496) self.total_steps_1 19070
# (pid=107496) self.total_steps_1 19071
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx
# (pid=107496) self.total_steps_1 19072
# (pid=107496) self.total_steps_1 19073
# (pid=107493) 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19074
# (pid=107496) self.total_steps_1 19075
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107521) <class 'collections.OrderedDict'> 0
# (pid=107521) GET_WEIGHT
# (pid=107496) self.total_steps_1 19076
# (pid=107496) self.total_steps_1 19077
# (pid=107496) self.total_steps_1 19078
# (pid=107496) self.total_steps_1 19079
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19080
# (pid=107496) self.total_steps_1 19081
# (pid=107496) self.total_steps_1 19082
# (pid=107496) self.total_steps_1 19083
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19084
# (pid=107496) self.total_steps_1 19085
# (pid=107496) self.total_steps_1 19086
# (pid=107496) self.total_steps_1 19087
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) GET_WEIGHT
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19088
# (pid=107496) self.total_steps_1 19089
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19090
# (pid=107496) self.total_steps_1 19091
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19092
# (pid=107496) self.total_steps_1 19093
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107496) self.total_steps_1 19094
# (pid=107496) self.total_steps_1 19095
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19096
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19097
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19098
# (pid=107496) self.total_steps_1 19099
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19100
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19101
# (pid=107496) self.total_steps_1 19102
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19103
# (pid=107496) self.total_steps_1 19104
# (pid=107496) self.total_steps_1 19105
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19106
# (pid=107496) self.total_steps_1 19107
# (pid=107496) self.total_steps_1 19108
# (pid=107521)
# (pid=107521) Done in actor index: 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19109
# (pid=107496) self.total_steps_1 19110
# (pid=107496) self.total_steps_1 19111
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19112
# (pid=107496) self.total_steps_1 19113
# (pid=107521)
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19114
# (pid=107496) self.total_steps_1 19115
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19116
# (pid=107496) self.total_steps_1 19117
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19118
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 19119
# (pid=107496) self.total_steps_1 19120
# (pid=107496) self.total_steps_1 19121
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) GET_WEIGHT
# (pid=107496) self.total_steps_1 19122
# (pid=107496) self.total_steps_1 19123
# (pid=107496) self.total_steps_1 19124
# (pid=107496) self.total_steps_1 19125
# (pid=107496) self.total_steps_1 19126
# (pid=107496) self.total_steps_1 19127
# (pid=107496) self.total_steps_1 19128
# (pid=107496) self.total_steps_1 19129
# (pid=107496) self.total_steps_1 19130
# (pid=107496) self.total_steps_1 19131
# (pid=107485) <class 'collections.OrderedDict'> 1
# (pid=107485) GET_WEIGHT
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 19132
# (pid=107496) self.total_steps_1 19133
# (pid=107496) self.total_steps_1 19134
# (pid=107496) self.total_steps_1 19135
# (pid=107496) self.total_steps_1 19136
# (pid=107496) self.total_steps_1 19137
# (pid=107496) self.total_steps_1 19138
# (pid=107496) self.total_steps_1 19139
# (pid=107496) self.total_steps_1 19140
# (pid=107496) self.total_steps_1 19141
# (pid=107496) self.total_steps_1 19142
# (pid=107496) self.total_steps_1 19143
# (pid=107496) self.total_steps_1 19144
# (pid=107496) self.total_steps_1 19145
# (pid=107496) self.total_steps_1 19146
# (pid=107496) self.total_steps_1 19147
# (pid=107496) self.total_steps_1 19148
# (pid=107496) self.total_steps_1 19149
# (pid=107496) self.total_steps_1 19150
# (pid=107496) self.total_steps_1 19151
# (pid=107496) self.total_steps_1 19152
# (pid=107496) self.total_steps_1 19153
# (pid=107496) self.total_steps_1 19154
# (pid=107496) self.total_steps_1 19155
# (pid=107496) self.total_steps_1 19156
# (pid=107496) self.total_steps_1 19157
# (pid=107496) self.total_steps_1 19158
# (pid=107496) self.total_steps_1 19159
# (pid=107496) self.total_steps_1 19160
# (pid=107496) self.total_steps_1 19161
# (pid=107496) self.total_steps_1 19162
# (pid=107496) self.total_steps_1 19163
# (pid=107496) self.total_steps_1 19164
# (pid=107496) self.total_steps_1 19165
# (pid=107496) self.total_steps_1 19166
# (pid=107496) self.total_steps_1 19167
# (pid=107496) self.total_steps_1 19168
# (pid=107496) self.total_steps_1 19169
# (pid=107496) self.total_steps_1 19170
# (pid=107496) self.total_steps_1 19171
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 19172
# (pid=107496) self.total_steps_1 19173
# (pid=107496) self.total_steps_1 19174
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 19175
# (pid=107496) self.total_steps_1 19176
# (pid=107496) self.total_steps_1 19177
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 19178
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 19179
# (pid=107496) self.total_steps_1 19180
# (pid=107496) self.total_steps_1 19181
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 19182
# (pid=107496) self.total_steps_1 19183
# (pid=107496) self.total_steps_1 19184
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) GET_WEIGHT
# (pid=107496) self.total_steps_1 19185
# (pid=107496) self.total_steps_1 19186
# (pid=107496) self.total_steps_1 19187
# (pid=107496) self.total_steps_1 19188
# (pid=107496) self.total_steps_1 19189
# (pid=107493) <class 'collections.OrderedDict'> 2
# (pid=107493) GET_WEIGHT
# (pid=107496) self.total_steps_1 19190
# (pid=107496) self.total_steps_1 19191
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19192
# (pid=107496) self.total_steps_1 19193
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19194
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19195
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107496) self.total_steps_1 19196
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19197
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19198
# (pid=107496) self.total_steps_1 19199
# (pid=107496) self.total_steps_1 19200
# (pid=107496) self.total_steps_1 19201
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19202
# (pid=107496) self.total_steps_1 19203
# (pid=107496) self.total_steps_1 19204
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19205
# (pid=107496) self.total_steps_1 19206
# (pid=107496) self.total_steps_1 19207
# (pid=107496) self.total_steps_1 19208
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19209
# (pid=107496) self.total_steps_1 19210
# (pid=107496) self.total_steps_1 19211
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19212
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 19213
# (pid=107496) self.total_steps_1 19214
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx
# (pid=107493)
# (pid=107496) self.total_steps_1 19215
# (pid=107496) self.total_steps_1 19216
# (pid=107496) self.total_steps_1 19217
# (pid=107496) self.total_steps_1 19218
# (pid=107493) 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) GET_WEIGHT
# (pid=107496) self.total_steps_1 19219
# (pid=107496) self.total_steps_1 19220
# (pid=107496) self.total_steps_1 19221
# (pid=107496) self.total_steps_1 19222
# (pid=107496) self.total_steps_1 19223
# (pid=107496) self.total_steps_1 19224
# (pid=107496) self.total_steps_1 19225
# (pid=107496) self.total_steps_1 19226
# (pid=107496) self.total_steps_1 19227
# (pid=107496) self.total_steps_1 19228
# (pid=107496) self.total_steps_1 19229
# (pid=107496) self.total_steps_1 19230
# (pid=107496) self.total_steps_1 19231
# (pid=107496) self.total_steps_1 19232
# (pid=107496) self.total_steps_1 19233
# (pid=107496) self.total_steps_1 19234
# (pid=107521) <class 'collections.OrderedDict'> 0
# (pid=107521) GET_WEIGHT
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# ...
# (pid=107485) GET_WEIGHT
# (pid=107496) self.total_steps_1 20177
# (pid=107496) self.total_steps_1 20178
# (pid=107496) self.total_steps_1 20179
# (pid=107496) self.total_steps_1 20180
# (pid=107496) self.total_steps_1 20181
# (pid=107496) self.total_steps_1 20182
# (pid=107496) self.total_steps_1 20183
# (pid=107496) self.total_steps_1 20184
# (pid=107496) self.total_steps_1 20185
# (pid=107496) self.total_steps_1 20186
# (pid=107496) self.total_steps_1 20187
# (pid=107496) self.total_steps_1 20188
# (pid=107496) self.total_steps_1 20189
# (pid=107496) self.total_steps_1 20190
# (pid=107496) self.total_steps_1 20191
# (pid=107496) self.total_steps_1 20192
# (pid=107496) self.total_steps_1 20193
# (pid=107496) self.total_steps_1 20194
# (pid=107496) self.total_steps_1 20195
# (pid=107496) self.total_steps_1 20196
# (pid=107496) self.total_steps_1 20197
# (pid=107496) self.total_steps_1 20198
# (pid=107496) self.total_steps_1 20199
# (pid=107496) self.total_steps_1 20200
# (pid=107496) self.total_steps_1 20201
# (pid=107496) self.total_steps_1 20202
# (pid=107496) self.total_steps_1 20203
# (pid=107496) self.total_steps_1 20204
# (pid=107496) self.total_steps_1 20205
# (pid=107496) self.total_steps_1 20206
# (pid=107496) self.total_steps_1 20207
# (pid=107496) self.total_steps_1 20208
# (pid=107496) self.total_steps_1 20209
# (pid=107496) self.total_steps_1 20210
# (pid=107496) self.total_steps_1 20211
# (pid=107496) self.total_steps_1 20212
# (pid=107496) self.total_steps_1 20213
# (pid=107496) self.total_steps_1 20214
# (pid=107496) self.total_steps_1 20215
# (pid=107496) self.total_steps_1 20216
# (pid=107493) <class 'collections.OrderedDict'> 2
# (pid=107493) GET_WEIGHT
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 20217
# (pid=107496) self.total_steps_1 20218
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 20219
# (pid=107496) self.total_steps_1 20220
# (pid=107496) self.total_steps_1 20221
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 20222
# (pid=107496) self.total_steps_1 20223
# (pid=107496) self.total_steps_1 20224
# (pid=107496) self.total_steps_1 20225
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 20226
# (pid=107496) self.total_steps_1 20227
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 20228
# (pid=107496) self.total_steps_1 20229
# (pid=107496) self.total_steps_1 20230
# (pid=107496) self.total_steps_1 20231
# (pid=107496) self.total_steps_1 20232
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 20233
# (pid=107496) self.total_steps_1 20234
# (pid=107496) self.total_steps_1 20235
# (pid=107496) self.total_steps_1 20236
# (pid=107496) self.total_steps_1 20237
# (pid=107496) self.total_steps_1 20238
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107496) self.total_steps_1 20239
# (pid=107496) self.total_steps_1 20240
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 20241
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 20242
# (pid=107496) self.total_steps_1 20243
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107496) self.total_steps_1 20244
# (pid=107493) store executed in actor idx 2
# (pid=107493) store executed in actor idx 2
# (pid=107493) Done in actor index: 2
# (pid=107496) self.total_steps_1 20245
# (pid=107496) self.total_steps_1 20246
# (pid=107493) GET_WEIGHT
# (pid=107496) self.total_steps_1 20247
# (pid=107496) self.total_steps_1 20248
# (pid=107496) self.total_steps_1 20249
# (pid=107496) self.total_steps_1 20250
# (pid=107496) self.total_steps_1 20251
# (pid=107496) self.total_steps_1 20252
# (pid=107496) self.total_steps_1 20253
# (pid=107496) self.total_steps_1 20254
# (pid=107496) self.total_steps_1 20255
# (pid=107496) self.total_steps_1 20256
# (pid=107496) self.total_steps_1 20257
# (pid=107496) self.total_steps_1 20258
# (pid=107496) self.total_steps_1 20259
# (pid=107496) self.total_steps_1 20260
# (pid=107496) self.total_steps_1 20261
# (pid=107496) self.total_steps_1 20262
# (pid=107496) self.total_steps_1 20263
# (pid=107496) self.total_steps_1 20264
# (pid=107496) self.total_steps_1 20265
# (pid=107496) self.total_steps_1 20266
# (pid=107496) self.total_steps_1 20267
# (pid=107521) <class 'collections.OrderedDict'> 0
# (pid=107521) GET_WEIGHT
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 20268
# (pid=107496) self.total_steps_1 20269
# (pid=107496) self.total_steps_1 20270
# (pid=107496) self.total_steps_1 20271
# (pid=107496) self.total_steps_1 20272
# (pid=107496) self.total_steps_1 20273
# (pid=107496) self.total_steps_1 20274
# (pid=107496) self.total_steps_1 20275
# (pid=107496) self.total_steps_1 20276
# (pid=107496) self.total_steps_1 20277
# (pid=107496) self.total_steps_1 20278
# (pid=107496) self.total_steps_1 20279
# (pid=107496) self.total_steps_1 20280
# (pid=107496) self.total_steps_1 20281
# (pid=107496) self.total_steps_1 20282
# (pid=107496) self.total_steps_1 20283
# (pid=107496) self.total_steps_1 20284
# (pid=107496) self.total_steps_1 20285
# (pid=107496) self.total_steps_1 20286
# (pid=107496) self.total_steps_1 20287
# (pid=107496) self.total_steps_1 20288
# (pid=107496) self.total_steps_1 20289
# (pid=107496) self.total_steps_1 20290
# (pid=107496) self.total_steps_1 20291
# (pid=107496) self.total_steps_1 20292
# (pid=107496) self.total_steps_1 20293
# (pid=107496) self.total_steps_1 20294
# (pid=107496) self.total_steps_1 20295
# (pid=107496) self.total_steps_1 20296
# (pid=107496) self.total_steps_1 20297
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 20298
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 20299
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 20300
# (pid=107496) self.total_steps_1 20301
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 20302
# (pid=107496) self.total_steps_1 20303
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 20304
# (pid=107496) self.total_steps_1 20305
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 20306
# (pid=107496) self.total_steps_1 20307
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 20308
# (pid=107521)
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 20309
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx
# (pid=107496) self.total_steps_1 20310
# (pid=107496) self.total_steps_1 20311
# (pid=107521)  0
# (pid=107521) store executed in actor idx 0
# (pid=107496) self.total_steps_1 20312
# (pid=107521) store executed in actor idx 0
# (pid=107521) store executed in actor idx 0
# (pid=107521) Done in actor index: 0
# (pid=107521) GET_WEIGHT
# (pid=107496) self.total_steps_1 20313
# (pid=107496) self.total_steps_1 20314
# (pid=107496) self.total_steps_1 20315
# (pid=107496) self.total_steps_1 20316
# (pid=107496) self.total_steps_1 20317
# (pid=107496) self.total_steps_1 20318
# (pid=107496) self.total_steps_1 20319
# (pid=107496) self.total_steps_1 20320
# (pid=107496) self.total_steps_1 20321
# (pid=107496) self.total_steps_1 20322
# (pid=107496) self.total_steps_1 20323
# (pid=107485) <class 'collections.OrderedDict'> 1
# (pid=107485) GET_WEIGHT
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 20324
# (pid=107496) self.total_steps_1 20325
# (pid=107496) self.total_steps_1 20326
# (pid=107496) self.total_steps_1 20327
# (pid=107496) self.total_steps_1 20328
# (pid=107496) self.total_steps_1 20329
# (pid=107496) self.total_steps_1 20330
# (pid=107496) self.total_steps_1 20331
# (pid=107496) self.total_steps_1 20332
# (pid=107496) self.total_steps_1 20333
# (pid=107496) self.total_steps_1 20334
# (pid=107496) self.total_steps_1 20335
# (pid=107496) self.total_steps_1 20336
# (pid=107496) self.total_steps_1 20337
# (pid=107496) self.total_steps_1 20338
# (pid=107496) self.total_steps_1 20339
# (pid=107496) self.total_steps_1 20340
# (pid=107496) self.total_steps_1 20341
# (pid=107496) self.total_steps_1 20342
# (pid=107496) self.total_steps_1 20343
# (pid=107496) self.total_steps_1 20344
# (pid=107496) self.total_steps_1 20345
# (pid=107496) self.total_steps_1 20346
# (pid=107496) self.total_steps_1 20347
# (pid=107496) self.total_steps_1 20348
# (pid=107496) self.total_steps_1 20349
# (pid=107496) self.total_steps_1 20350
# (pid=107496) self.total_steps_1 20351
# (pid=107496) self.total_steps_1 20352
# (pid=107496) self.total_steps_1 20353
# (pid=107496) self.total_steps_1 20354
# (pid=107496) self.total_steps_1 20355
# (pid=107496) self.total_steps_1 20356
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 20357
# (pid=107496) self.total_steps_1 20358
# (pid=107496) self.total_steps_1 20359
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 20360
# (pid=107496) self.total_steps_1 20361
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107496) self.total_steps_1 20362
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 20363
# (pid=107496) self.total_steps_1 20364
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 20365
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107496) self.total_steps_1 20366
# (pid=107496) self.total_steps_1 20367
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) store executed in actor idx 1
# (pid=107485) Done in actor index: 1
# (pid=107485) GET_WEIGHT
# (pid=107496) self.total_steps_1 20368
# (pid=107496) self.total_steps_1 20369
# (pid=107496) self.total_steps_1 20370
# (pid=107496) self.total_steps_1 20371
